# %% [markdown]
# # datatime 모듈 사용하기

# %%
from datetime import datetime

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 10, 21, 13, 23, 38, 614308)

# %%
now = datetime.now()
print(now)
# Out:
# 2025-10-21 13:23:43.309027

# %%
print(type(now))
# Out:
# <class 'datetime.datetime'>

# %%
now.year
# Out:
# 2025

# %%
now.month
# Out:
# 10

# %%
now.day
# Out:
# 21

# %%
print(f"{now.year}-{now.month:02d}-{now.day:02d}")
# Out:
# 2025-10-21

# %%
now.hour
# Out:
# 13

# %%
now.minute
# Out:
# 23

# %%
now.second
# Out:
# 43

# %%
now.strftime("%Y.%m.%d %H:%M:%S")
# Out:
# '2025.10.21 13:23:43'

# %%
now.strftime("%y.%m.%d %H:%M:%S")
# Out:
# '25.10.21 13:23:43'

# %% [markdown]
# # OS모듈
# * cmd 명령어를 python 코드에서 실행하는 모듈

# %%
import os

# %%
# 내가 사용하는 컴퓨터의 기본정보 출력하기
print("현재 운영체제: ", os.name)
print("현재 사용하는 폴더: ", os.getcwd())
print("현재 폴더 내부의 파일 리스트: ", os.listdir())
# Out:
# 현재 운영체제:  nt
# 현재 사용하는 폴더:  c:\fintech3\04Python
# 현재 폴더 내부의 파일 리스트:  ['.ipynb_checkpoints', '01주피터노트북사용법.ipynb', '03변수_자료형_연산자.ipynb', '04문자열과_문자열 함수_input.ipynb', '05리스트와 튜플 사용하기.ipynb', '06딕셔너리사용하기.ipynb', '07서식 지정자와 문자열 포메팅.ipynb', '08조건문.ipynb', '09반복문_for_while.ipynb', '10리스트표현식_파일읽기쓰기_json자료정리.ipynb', '12함수만들기_예외처리.ipynb', '13클래스_객체지향형프로그래밍.ipynb', '14JSON언패킹2_호텔스닷컴리뷰json구조.txt', '14모듈사용하기_만들기.ipynb', '15실전데이터정리_호텔스닷컴에서 원하는 자료 추출하기.ipynb', 'data', 'mymodule.py', 'new_name.txt', 'testdir', 'untitled.txt', '오은상__연습문제_01_print.ipynb', '오은상_딕셔너리_30문제.ipynb', '오은상_리스트_튜플_20문제.ipynb', '오은상_파이썬_300제.ipynb', '호텔정보추출하기.txt']

# %%
# 현재 위치에서 폴더 만들기
os.mkdir("testdir")

# %%
# 현재 위치에서 폴더 삭제하기
os.rmdir("testdir")

# %%
# cmd 명령어 실행하기 실행완료 0, 실행실패 1
os.system("tree")
# Out:
# 0

# %%
# 파일을 생성하고 파일 이름 변경하기
with open("original.txt", "w") as file:
    file.write("안녕하세요")

# %%
os.rename("original.txt", "new_name.txt")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 os.rename("original.txt", "new_name.txt")
#
# FileExistsError: [WinError 183] 파일이 이미 있으므로 만들 수 없습니다: 'original.txt' -> 'new_name.txt'

# %%
# 폴더가 있는지 확인하고 없으면 폴더 생성하기
if not os.path.exists("./testdir"):
    os.mkdir("testdir")
else:
    print("testdir이 이미 있습니다.")

# %%
# 환경변수에 변수와 값 추가하기/ 읽어오기, 현재파일이 실행되는 동안에만 저장됨
os.environ['key'] = "value"

# 등록된 환경변수 값 불러오기
print(os.environ.get('key'))
# Out:
# value

# %%
from mymodule import Cal, add

# %%
add(3,4)
# Out:
# 7

# %%
sam = Cal(3, 4)

# %%
sam.add()
# Out:
# 7

# %%
sam.sub()
# Out:
# -1
