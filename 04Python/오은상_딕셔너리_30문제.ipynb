# %%
# 1.
empty_dict = {}
print(empty_dict)
# Out:
# {}

# %%
# 2.
person = {"name": "Alice", "age": 25, "city": "Seoul"}
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul'}

# %%
# 3.
print(person["name"])
# Out:
# Alice

# %%
# 4.
print(person["age"])
# Out:
# 25

# %%
# 5.
person["job"] = "Enjineer"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Seoul', 'job': 'Enjineer'}

# %%
# 6.
person["city"] = "Busan"
print(person)
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Busan', 'job': 'Enjineer'}

# %%
# 7.
del person["age"]
print(person)
# Out:
# {'name': 'Alice', 'city': 'Busan', 'job': 'Enjineer'}

# %%
# 8.
print(person.keys())
# Out:
# dict_keys(['name', 'city', 'job'])

# %%
# 9.
print(person.values())
# Out:
# dict_values(['Alice', 'Busan', 'Enjineer'])

# %%
# 10.
print(person.items())
# Out:
# dict_items([('name', 'Alice'), ('city', 'Busan'), ('job', 'Enjineer')])

# %%
# 11.
print("email" in person)
# Out:
# False

# %%
# 12.
removed_value = person.pop("job")
print(f'"{removed_value}"')
print(person)
# Out:
# "Enjineer"
# {'name': 'Alice', 'city': 'Busan'}

# %%
# 13.
person.clear()
print(person)
# Out:
# {}

# %%
# 14.
student = {"name": "Bob", "grades":
          {"math": 85, "science": 90, "history": 80}}
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80}}

# %%
# 15.
print(student["grades"]["science"])
# Out:
# 90

# %%
# 16.
student["grades"]["english"] = 95
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 85, 'science': 90, 'history': 80, 'english': 95}}

# %%
# 17.
student["grades"]["math"] = 88
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'history': 80, 'english': 95}}

# %%
# 18.
del student["grades"]["history"]
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}}

# %%
# 19.
total_score = sum(student['grades'].values())
student.setdefault('total', total_score)
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 95}, 'total': 273}

# %%
# 20.
student['grades'].update({'english': 100, 'history': 80})
print(student)
# Out:
# {'name': 'Bob', 'grades': {'math': 88, 'science': 90, 'english': 100, 'history': 80}, 'total': 273}

# %%
# 21.
courses = dict(programming={'python': 50, 'java': 30, 'Cpp': 20},
              design={'Photoshop': 25, 'Illustrator': 15})
print(courses)
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 20}, 'design': {'Photoshop': 25, 'Illustrator': 15}}

# %%
# 22.
print(courses["programming"]["python"])
# Out:
# 50

# %%
# 23.
courses["programming"]["Cpp"] = 25
print(courses["programming"])
# Out:
# {'python': 50, 'java': 30, 'Cpp': 25}

# %%
# 24.
del courses["design"]["Photoshop"]
print(courses)
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25}, 'design': {'Illustrator': 15}}

# %%
# 25.
courses["programming"]["HavaScript"] = 40
print(courses["programming"])
# Out:
# {'python': 50, 'java': 30, 'Cpp': 25, 'HavaScript': 40}

# %%
# 26.
print(courses.keys())
# Out:
# dict_keys(['programming', 'design'])

# %%
# 27.
print(courses["design"])
# Out:
# {'Illustrator': 15}

# %%
# 28.
del courses["design"]
print(courses)
# Out:
# {'programming': {'python': 50, 'java': 30, 'Cpp': 25, 'HavaScript': 40}}

# %%
# 29.
print("programming" in courses)
# Out:
# True

# %%
# 30.
print(courses.get("design", "design key 없음"))
# Out:
# design key 없음
