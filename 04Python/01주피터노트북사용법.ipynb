# %% [markdown]
# <h1>주피터 노트북 사용법</h1>
# <ul>
#     <li>코딩모드</li>
#     <li>메모모드</li>
#     </ul>

# %% [markdown]
# #은 h1 태그
# ##는 h2 태그
# ###는 h3 태그

# %% [markdown]
# #ul은 \* 로 표시 하위 항목은 들여쓰기 후*
# * 목록
#   * 세부목록1
#   * 세부목록2
#   * 세부목록3

# %% [markdown]
# 글씨를 굵게 만들기 \**내용\**
# 글씨를 **굵게** 만들어 보아요.

# %%
#링크걸기 \[링크이름\]\(링크주소\)

# %%
1+1
# Out:
# 2

# %%
a=10

# %%
print(a)
# Out:
# 10

# %%
a
# Out:
# 10

# %%
b = 20

# %%
b
# Out:
# 20

# %%
c = 30

# %%
c
# Out:
# 30
