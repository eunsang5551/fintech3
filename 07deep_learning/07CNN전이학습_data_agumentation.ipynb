# %% [markdown]
# # CNN전이학습_data_augmentation
# * 전이학습: 사전에 훈련된 모델을 가져와서 사용하는 것
# * data_agmentation: 이미지 데이터의 경우 데이터가 적어서 확보가 어려움, 비쌈, 기존 이미지데이터에 변형을 가해서 데이터 수를 늘리는 작업(회전, 확대, 축소, 자르기)
# # Image Augmentation
# * 학습데이터 부족을 해결하기 위해서 이미지에 변형을 가해 새로운 이미지를 만들어 주는 것

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
from tensorflow.keras.preprocessing.image import img_to_array, ImageDataGenerator, array_to_img, load_img
# Out:
# 2025-12-04 11:16:57.566608: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-04 11:16:57.610985: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-04 11:17:00.195863: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.

# %%
image = load_img("./data/bird.jpg")
image_array = img_to_array(image)
image_array.shape
# Out:
# (703, 454, 3)

# %%
plt.imshow(image)
plt.show()

# %% [markdown]
# # Image Augmenttation(이미지 증폭)

# %%
imggen = ImageDataGenerator(
        rescale=1./255,
        rotation_range=40,
        width_shift_range=0.3,
        height_shift_range=0.2,
        shear_range=0.6,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')

# %% [markdown]
# # 차원 늘리기

# %%
(1,) + image_array.shape
# Out:
# (1, 703, 454, 3)

# %%
image_array = image_array.reshape((1,) + image_array.shape)

# %%
image_array.shape
# Out:
# (1, 703, 454, 3)

# %%
fig,axes = plt.subplots(5,4,figsize=(9,9))
axes = axes.ravel()
for i, batch in enumerate(imggen.flow(image_array,batch_size=1)):
    if i >= 20:
        break
    augmented_image = array_to_img(batch[0])
    axes[i].imshow(augmented_image)
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # image_augemtation을 이용한 개/고양이 분류 모델 만들기

# %%
# 데이터 로드
train_dir = "./data/train/"
valid_dir = "./data/validation/"
batch_size = 16# 한 번에 불러오는 사진의 갸수, 분석 모델에 따라서 16, 32 사이로 지정
image_size = (224, 224) # 모델의 입력 크기에 맞춤

# %%
# 이미지 증강
train_aug = ImageDataGenerator(
        rescale=1./255,
        rotation_range=40,
        width_shift_range=0.3,
        height_shift_range=0.2,
        shear_range=0.6,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest')
valid_aug = ImageDataGenerator(rescale=1./255)

# 이미지 제너레이터
train_gen = train_aug.flow_from_directory(
            train_dir,
            target_size=image_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=True,
            seed=42
            )

valid_gen = valid_aug.flow_from_directory(
            valid_dir,
            target_size=image_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=True,
            seed=42
            )

X_batch, y_batch = next(train_gen)
print(X_batch.shape)
print(y_batch.shape)
print(train_gen.class_indices)
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.
# (16, 224, 224, 3)
# (16, 2)
# {'Cat': 0, 'Dog': 1}

# %% [markdown]
# # CNN을 이용한 개/고양이 분류

# %%
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Input, Dropout
from keras.callbacks import EarlyStopping, ModelCheckpoint

# %%
cnn_model = Sequential()
cnn_model.add(Input(shape=(224, 224, 3)))
cnn_model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
cnn_model.add(MaxPooling2D(2,2))
cnn_model.add(Flatten())
cnn_model.add(Dense(128, activation='relu'))
cnn_model.add(Dropout(0.25))
cnn_model.add(Dense(64, activation='relu'))
cnn_model.add(Dense(2, activation='softmax'))
cnn_model.summary()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764815939.716373    2393 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1347 MB memory:  -> device: 0, name: NVIDIA GeForce MX450, pci bus id: 0000:01:00.0, compute capability: 7.5
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 52, 52, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 21632)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     2,769,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,815,266 (10.74 MB)
#  Trainable params: 2,815,266 (10.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
cnn_model.compile(loss="categorical_crossentropy",optimizer='adam',metrics=['accuracy'])
model_path = "./model/CNN_catndog.keras"
chechpoint = ModelCheckpoint(filepath=model_path,save_best_only=True)
early_stop = EarlyStopping(patience=10,restore_best_weights=True)
cnn_history = cnn_model.fit(train_gen, validation_data=valid_gen, epochs=1000,
                   callbacks=[chechpoint,early_stop])
plt.figure(figsize=(8,5))
plt.plot(cnn_history.history['loss'])
plt.plot(cnn_history.history['val_loss'])
plt.xlabel("epoches")
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/1000
# 2025-12-04 11:46:03.626817: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f2a0c015c30 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-04 11:46:03.626857: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce MX450, Compute Capability 7.5
# 2025-12-04 11:46:03.729654: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-04 11:46:04.110353: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91600
# 2025-12-04 11:46:05.096961: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 11:46:05.368432: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,64,109,109]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,32,111,111]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 11:46:05.993511: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,32,52,52]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,54,54]{3,2,1,0}, f32[32,64,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 11:46:07.598473: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-04 11:46:07.809220: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2025-12-04 11:46:08.043852: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
#  2/25 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.4531 - loss: 0.8215
# I0000 00:00:1764816372.192513    2495 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 498ms/step - accuracy: 0.4932 - loss: 0.7512
# 2025-12-04 11:46:25.599464: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,32,222,222]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,3,224,224]{3,2,1,0}, f32[32,3,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 11:46:25.775232: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,64,109,109]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,32,111,111]{3,2,1,0}, f32[64,32,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 11:46:26.378687: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,32,52,52]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,54,54]{3,2,1,0}, f32[32,64,3,3]{3,2,1,0}, f32[32]{0}), window={size=3x3}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kRelu","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 732ms/step - accuracy: 0.4987 - loss: 0.7153 - val_accuracy: 0.5000 - val_loss: 0.6930
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 590ms/step - accuracy: 0.5273 - loss: 0.6926 - val_accuracy: 0.5000 - val_loss: 0.6928
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 463ms/step - accuracy: 0.5273 - loss: 0.6934 - val_accuracy: 0.5102 - val_loss: 0.6920
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 462ms/step - accuracy: 0.5195 - loss: 0.6921 - val_accuracy: 0.5102 - val_loss: 0.6920
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 389ms/step - accuracy: 0.5247 - loss: 0.6917 - val_accuracy: 0.5204 - val_loss: 0.6905
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 353ms/step - accuracy: 0.5273 - loss: 0.6917 - val_accuracy: 0.5714 - val_loss: 0.6802
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 443ms/step - accuracy: 0.5455 - loss: 0.6921 - val_accuracy: 0.5306 - val_loss: 0.6885
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 410ms/step - accuracy: 0.5558 - loss: 0.6855 - val_accuracy: 0.5306 - val_loss: 0.6894
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 392ms/step - accuracy: 0.5221 - loss: 0.6905 - val_accuracy: 0.5306 - val_loss: 0.6897
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 322ms/step - accuracy: 0.5455 - loss: 0.6873 - val_accuracy: 0.5612 - val_loss: 0.6810
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 310ms/step - accuracy: 0.5506 - loss: 0.6879 - val_accuracy: 0.5612 - val_loss: 0.6735
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 290ms/step - accuracy: 0.5558 - loss: 0.6916 - val_accuracy: 0.5612 - val_loss: 0.6755
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 334ms/step - accuracy: 0.5558 - loss: 0.6883 - val_accuracy: 0.5612 - val_loss: 0.6689
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 275ms/step - accuracy: 0.5610 - loss: 0.6841 - val_accuracy: 0.5714 - val_loss: 0.6786
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 328ms/step - accuracy: 0.5325 - loss: 0.6853 - val_accuracy: 0.5612 - val_loss: 0.6777
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 318ms/step - accuracy: 0.5558 - loss: 0.6938 - val_accuracy: 0.5714 - val_loss: 0.6871
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 304ms/step - accuracy: 0.5455 - loss: 0.6898 - val_accuracy: 0.5612 - val_loss: 0.6851
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 292ms/step - accuracy: 0.5403 - loss: 0.6914 - val_accuracy: 0.5612 - val_loss: 0.6835
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 300ms/step - accuracy: 0.5481 - loss: 0.6876 - val_accuracy: 0.5306 - val_loss: 0.6849
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 276ms/step - accuracy: 0.5351 - loss: 0.6896 - val_accuracy: 0.5306 - val_loss: 0.6865
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 265ms/step - accuracy: 0.5610 - loss: 0.6859 - val_accuracy: 0.5714 - val_loss: 0.6773
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 0.5922 - loss: 0.6805 - val_accuracy: 0.5918 - val_loss: 0.6712
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 529ms/step - accuracy: 0.5403 - loss: 0.6916 - val_accuracy: 0.4796 - val_loss: 0.6985

# %%
import tensorflow as tf

# %%
cnn_model2 = Sequential()
cnn_model2.add(Input(shape=(224, 224, 3)))
cnn_model2.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
cnn_model2.add(MaxPooling2D(2,2))
cnn_model2.add(Conv2D(64, kernel_size=(3,3), activation='relu'))
cnn_model2.add(MaxPooling2D(2,2))
cnn_model2.add(Conv2D(32, kernel_size=(3,3), activation='relu'))
cnn_model2.add(MaxPooling2D(2,2))
cnn_model2.add(Flatten())
cnn_model2.add(Dense(128, activation='relu'))
cnn_model2.add(Dropout(0.25))
cnn_model2.add(Dense(64, activation='relu'))
cnn_model2.add(Dense(2, activation='softmax'))
cnn_model2.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_3 (Conv2D)               │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 111, 111, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 109, 109, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_4 (MaxPooling2D)  │ (None, 54, 54, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 52, 52, 32)     │        18,464 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_5 (MaxPooling2D)  │ (None, 26, 26, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_1 (Flatten)             │ (None, 21632)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 128)            │     2,769,024 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 2)              │           130 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,815,266 (10.74 MB)
#  Trainable params: 2,815,266 (10.74 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
cus_opt = tf.keras.optimizers.Adam(learning_rate=1e-4)

# %%
cnn_model2.compile(loss="categorical_crossentropy",optimizer=cus_opt,metrics=['accuracy'])
model_path = "./model/CNN_catndog2.keras"
chechpoint = ModelCheckpoint(filepath=model_path,save_best_only=True)
early_stop = EarlyStopping(patience=10,restore_best_weights=True)
cnn_history = cnn_model.fit(train_gen, validation_data=valid_gen, epochs=1000,
                   callbacks=[chechpoint,early_stop])
plt.figure(figsize=(8,5))
plt.plot(cnn_history.history['loss'])
plt.plot(cnn_history.history['val_loss'])
plt.xlabel("epoches")
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.5558 - loss: 0.6852 - val_accuracy: 0.5714 - val_loss: 0.6753
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.5662 - loss: 0.6784 - val_accuracy: 0.5714 - val_loss: 0.6700
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.5351 - loss: 0.6888 - val_accuracy: 0.5510 - val_loss: 0.6846
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - accuracy: 0.5325 - loss: 0.6890 - val_accuracy: 0.5408 - val_loss: 0.6933
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 0.5247 - loss: 0.6878 - val_accuracy: 0.5612 - val_loss: 0.6795
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - accuracy: 0.5481 - loss: 0.6781 - val_accuracy: 0.5408 - val_loss: 0.6734
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.5429 - loss: 0.6835 - val_accuracy: 0.5306 - val_loss: 0.6883
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 286ms/step - accuracy: 0.5506 - loss: 0.6873 - val_accuracy: 0.5408 - val_loss: 0.6822
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 316ms/step - accuracy: 0.5429 - loss: 0.6874 - val_accuracy: 0.6327 - val_loss: 0.6668
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 332ms/step - accuracy: 0.5506 - loss: 0.6805 - val_accuracy: 0.5816 - val_loss: 0.6761
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 341ms/step - accuracy: 0.5506 - loss: 0.6888 - val_accuracy: 0.5714 - val_loss: 0.6608
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 313ms/step - accuracy: 0.5039 - loss: 0.6982 - val_accuracy: 0.5204 - val_loss: 0.6786
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 407ms/step - accuracy: 0.5403 - loss: 0.6868 - val_accuracy: 0.5102 - val_loss: 0.6828
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 469ms/step - accuracy: 0.5195 - loss: 0.7011 - val_accuracy: 0.6224 - val_loss: 0.6675
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 0.5558 - loss: 0.6852 - val_accuracy: 0.5714 - val_loss: 0.6779
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 397ms/step - accuracy: 0.5974 - loss: 0.6796 - val_accuracy: 0.5612 - val_loss: 0.6779
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 400ms/step - accuracy: 0.5091 - loss: 0.7000 - val_accuracy: 0.4898 - val_loss: 0.7439
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 442ms/step - accuracy: 0.5481 - loss: 0.6813 - val_accuracy: 0.5306 - val_loss: 0.7427
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 403ms/step - accuracy: 0.5351 - loss: 0.6895 - val_accuracy: 0.5408 - val_loss: 0.6891
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 379ms/step - accuracy: 0.5532 - loss: 0.6842 - val_accuracy: 0.5612 - val_loss: 0.6855
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 453ms/step - accuracy: 0.5455 - loss: 0.6891 - val_accuracy: 0.5510 - val_loss: 0.6860

# %%
# best 모델 로드
cnn_best_model = load_model("./model/CNN_catndog2.keras")

# 클래스 이름 추출하기
class_indices = valid_gen.class_indices
class_names = [k for k, v in sorted(class_indices.items(), key=lambda x: x[1])]
validation_batch, label_batch = next(iter(valid_gen))

cnn_pred = cnn_best_model.predict(validation_batch)
pred_values = np.argmax(cnn_pred, axis=1)
true_values = np.argmax(label_batch, axis=1)

fig = plt.figure(figsize=(12,12))
fig.subplots_adjust(hspace=0.3)

num_images = min(16, validation_batch.shape[0])

for i in range(num_images):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    ax.imshow(validation_batch[i], cmap=plt.cm.gray_r)

    pred_label = class_names[pred_values[i]]
    true_label = class_names[true_values[i]]
    color = 'green' if pred_values[i] == true_values[i] else 'red'
    ax.set_title(f"Pred: {pred_label}", color=color, fontsize=12)
plt.show()

# loss와 accuracy 출력
loss, acc = cnn_best_model.evaluate(validation_batch, label_batch, verbose=0)
print(f"\ncnn_best_model평가 결과: Loss: {loss:.4f}, Accuracy: {acc:.4f}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 803ms/step
# cnn_best_model평가 결과: Loss: 0.6832, Accuracy: 0.5000

# %% [markdown]
# # 전이학습
# * 사전에 훈련된 모델을 가지고 새로운 데이터를 넣어서 튜닝을 하거나 결과를 출력
# * keras.applications에 있음.

# %% [markdown]
# # ResNet50
# * ResNet50에 사용할 경우, rescale=1./255는 제거하고 preprocessing_function=preprocess_input을 사용
# * Keras의 ResNet50은 입력 이미지를 BGR로 바꾸고 채널별 평균을 빼는 전처리를 필요로 하기 때문

# %%
from tensorflow.keras.layers import GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNet50, ResNet152V2
from tensorflow.keras.applications.resnet import preprocess_input

# %%
# ResNet50 맞는 이미지 증강기 (rescale제거 , preprocess_input 사용)
# 이미지 증강
train_aug = ImageDataGenerator(
        preprocessing_function=preprocess_input,
        rotation_range=40,
        width_shift_range=0.3,
        height_shift_range=0.2,
        shear_range=0.6,
        zoom_range=0.3,
       # horizontal_flip=True,
       # vertical_flip=True,
        fill_mode='nearest')
valid_aug = ImageDataGenerator(preprocessing_function=preprocess_input)

# 이미지 제너레이터
train_gen = train_aug.flow_from_directory(
            train_dir,
            target_size=image_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=True,
            seed=42
            )

valid_gen = valid_aug.flow_from_directory(
            valid_dir,
            target_size=image_size,
            batch_size=batch_size,
            class_mode='categorical',
            shuffle=True,
            seed=42
            )

X_batch, y_batch = next(train_gen)
print(X_batch.shape)
print(y_batch.shape)
print(train_gen.class_indices)
# Out:
# Found 385 images belonging to 2 classes.
# Found 98 images belonging to 2 classes.
# (16, 224, 224, 3)
# (16, 2)
# {'Cat': 0, 'Dog': 1}

# %%
base_model = ResNet50(include_top=False, weights='imagenet', input_tensor=None, input_shape=(224, 224, 3), pooling='avg')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 8s 0us/step

# %%
base_model.summary()
# Out:
# Model: "resnet50"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_2       │ (None, 224, 224,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 230, 230,  │          0 │ input_layer_2[0]… │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 112, 112,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_bn            │ (None, 112, 112,  │        256 │ conv1_conv[0][0]  │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_relu          │ (None, 112, 112,  │          0 │ conv1_bn[0][0]    │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pad           │ (None, 114, 114,  │          0 │ conv1_relu[0][0]  │
# │ (ZeroPadding2D)     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ pool1_pool          │ (None, 56, 56,    │          0 │ pool1_pad[0][0]   │
# │ (MaxPooling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_conv │ (None, 56, 56,    │      4,160 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_bn   │ (None, 56, 56,    │        256 │ conv2_block1_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_1_relu │ (None, 56, 56,    │          0 │ conv2_block1_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block1_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_bn   │ (None, 56, 56,    │        256 │ conv2_block1_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_2_relu │ (None, 56, 56,    │          0 │ conv2_block1_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_conv │ (None, 56, 56,    │     16,640 │ pool1_pool[0][0]  │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block1_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_0_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_0_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block1_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_add    │ (None, 56, 56,    │          0 │ conv2_block1_0_b… │
# │ (Add)               │ 256)              │            │ conv2_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block1_out    │ (None, 56, 56,    │          0 │ conv2_block1_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block1_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_bn   │ (None, 56, 56,    │        256 │ conv2_block2_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_1_relu │ (None, 56, 56,    │          0 │ conv2_block2_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block2_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_bn   │ (None, 56, 56,    │        256 │ conv2_block2_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_2_relu │ (None, 56, 56,    │          0 │ conv2_block2_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block2_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block2_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_add    │ (None, 56, 56,    │          0 │ conv2_block1_out… │
# │ (Add)               │ 256)              │            │ conv2_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block2_out    │ (None, 56, 56,    │          0 │ conv2_block2_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_conv │ (None, 56, 56,    │     16,448 │ conv2_block2_out… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_bn   │ (None, 56, 56,    │        256 │ conv2_block3_1_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_1_relu │ (None, 56, 56,    │          0 │ conv2_block3_1_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_conv │ (None, 56, 56,    │     36,928 │ conv2_block3_1_r… │
# │ (Conv2D)            │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_bn   │ (None, 56, 56,    │        256 │ conv2_block3_2_c… │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_2_relu │ (None, 56, 56,    │          0 │ conv2_block3_2_b… │
# │ (Activation)        │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_conv │ (None, 56, 56,    │     16,640 │ conv2_block3_2_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_3_bn   │ (None, 56, 56,    │      1,024 │ conv2_block3_3_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_add    │ (None, 56, 56,    │          0 │ conv2_block2_out… │
# │ (Add)               │ 256)              │            │ conv2_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2_block3_out    │ (None, 56, 56,    │          0 │ conv2_block3_add… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_conv │ (None, 28, 28,    │     32,896 │ conv2_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_bn   │ (None, 28, 28,    │        512 │ conv3_block1_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_1_relu │ (None, 28, 28,    │          0 │ conv3_block1_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block1_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_bn   │ (None, 28, 28,    │        512 │ conv3_block1_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_2_relu │ (None, 28, 28,    │          0 │ conv3_block1_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_conv │ (None, 28, 28,    │    131,584 │ conv2_block3_out… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block1_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_0_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_0_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block1_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_add    │ (None, 28, 28,    │          0 │ conv3_block1_0_b… │
# │ (Add)               │ 512)              │            │ conv3_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block1_out    │ (None, 28, 28,    │          0 │ conv3_block1_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block1_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_bn   │ (None, 28, 28,    │        512 │ conv3_block2_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_1_relu │ (None, 28, 28,    │          0 │ conv3_block2_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block2_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_bn   │ (None, 28, 28,    │        512 │ conv3_block2_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_2_relu │ (None, 28, 28,    │          0 │ conv3_block2_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block2_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block2_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_add    │ (None, 28, 28,    │          0 │ conv3_block1_out… │
# │ (Add)               │ 512)              │            │ conv3_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block2_out    │ (None, 28, 28,    │          0 │ conv3_block2_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block2_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_bn   │ (None, 28, 28,    │        512 │ conv3_block3_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_1_relu │ (None, 28, 28,    │          0 │ conv3_block3_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block3_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_bn   │ (None, 28, 28,    │        512 │ conv3_block3_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_2_relu │ (None, 28, 28,    │          0 │ conv3_block3_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block3_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block3_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_add    │ (None, 28, 28,    │          0 │ conv3_block2_out… │
# │ (Add)               │ 512)              │            │ conv3_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block3_out    │ (None, 28, 28,    │          0 │ conv3_block3_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_conv │ (None, 28, 28,    │     65,664 │ conv3_block3_out… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_bn   │ (None, 28, 28,    │        512 │ conv3_block4_1_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_1_relu │ (None, 28, 28,    │          0 │ conv3_block4_1_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_conv │ (None, 28, 28,    │    147,584 │ conv3_block4_1_r… │
# │ (Conv2D)            │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_bn   │ (None, 28, 28,    │        512 │ conv3_block4_2_c… │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_2_relu │ (None, 28, 28,    │          0 │ conv3_block4_2_b… │
# │ (Activation)        │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_conv │ (None, 28, 28,    │     66,048 │ conv3_block4_2_r… │
# │ (Conv2D)            │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_3_bn   │ (None, 28, 28,    │      2,048 │ conv3_block4_3_c… │
# │ (BatchNormalizatio… │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_add    │ (None, 28, 28,    │          0 │ conv3_block3_out… │
# │ (Add)               │ 512)              │            │ conv3_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv3_block4_out    │ (None, 28, 28,    │          0 │ conv3_block4_add… │
# │ (Activation)        │ 512)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_conv │ (None, 14, 14,    │    131,328 │ conv3_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_1_relu │ (None, 14, 14,    │          0 │ conv4_block1_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block1_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block1_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_2_relu │ (None, 14, 14,    │          0 │ conv4_block1_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_conv │ (None, 14, 14,    │    525,312 │ conv3_block4_out… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block1_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_0_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_0_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block1_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_add    │ (None, 14, 14,    │          0 │ conv4_block1_0_b… │
# │ (Add)               │ 1024)             │            │ conv4_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block1_out    │ (None, 14, 14,    │          0 │ conv4_block1_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block1_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_1_relu │ (None, 14, 14,    │          0 │ conv4_block2_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block2_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block2_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_2_relu │ (None, 14, 14,    │          0 │ conv4_block2_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block2_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block2_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_add    │ (None, 14, 14,    │          0 │ conv4_block1_out… │
# │ (Add)               │ 1024)             │            │ conv4_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block2_out    │ (None, 14, 14,    │          0 │ conv4_block2_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block2_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_1_relu │ (None, 14, 14,    │          0 │ conv4_block3_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block3_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block3_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_2_relu │ (None, 14, 14,    │          0 │ conv4_block3_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block3_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block3_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_add    │ (None, 14, 14,    │          0 │ conv4_block2_out… │
# │ (Add)               │ 1024)             │            │ conv4_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block3_out    │ (None, 14, 14,    │          0 │ conv4_block3_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block3_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_1_relu │ (None, 14, 14,    │          0 │ conv4_block4_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block4_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block4_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_2_relu │ (None, 14, 14,    │          0 │ conv4_block4_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block4_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block4_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_add    │ (None, 14, 14,    │          0 │ conv4_block3_out… │
# │ (Add)               │ 1024)             │            │ conv4_block4_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block4_out    │ (None, 14, 14,    │          0 │ conv4_block4_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block4_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_1_relu │ (None, 14, 14,    │          0 │ conv4_block5_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block5_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block5_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_2_relu │ (None, 14, 14,    │          0 │ conv4_block5_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block5_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block5_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_add    │ (None, 14, 14,    │          0 │ conv4_block4_out… │
# │ (Add)               │ 1024)             │            │ conv4_block5_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block5_out    │ (None, 14, 14,    │          0 │ conv4_block5_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_conv │ (None, 14, 14,    │    262,400 │ conv4_block5_out… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_1_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_1_relu │ (None, 14, 14,    │          0 │ conv4_block6_1_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_conv │ (None, 14, 14,    │    590,080 │ conv4_block6_1_r… │
# │ (Conv2D)            │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_bn   │ (None, 14, 14,    │      1,024 │ conv4_block6_2_c… │
# │ (BatchNormalizatio… │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_2_relu │ (None, 14, 14,    │          0 │ conv4_block6_2_b… │
# │ (Activation)        │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_conv │ (None, 14, 14,    │    263,168 │ conv4_block6_2_r… │
# │ (Conv2D)            │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_3_bn   │ (None, 14, 14,    │      4,096 │ conv4_block6_3_c… │
# │ (BatchNormalizatio… │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_add    │ (None, 14, 14,    │          0 │ conv4_block5_out… │
# │ (Add)               │ 1024)             │            │ conv4_block6_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv4_block6_out    │ (None, 14, 14,    │          0 │ conv4_block6_add… │
# │ (Activation)        │ 1024)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_conv │ (None, 7, 7, 512) │    524,800 │ conv4_block6_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block1_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block1_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block1_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_conv │ (None, 7, 7,      │  2,099,200 │ conv4_block6_out… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block1_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_0_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_0_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block1_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_add    │ (None, 7, 7,      │          0 │ conv5_block1_0_b… │
# │ (Add)               │ 2048)             │            │ conv5_block1_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block1_out    │ (None, 7, 7,      │          0 │ conv5_block1_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block1_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block2_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block2_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block2_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block2_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block2_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_add    │ (None, 7, 7,      │          0 │ conv5_block1_out… │
# │ (Add)               │ 2048)             │            │ conv5_block2_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block2_out    │ (None, 7, 7,      │          0 │ conv5_block2_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_conv │ (None, 7, 7, 512) │  1,049,088 │ conv5_block2_out… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_1_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_1_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_1_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_conv │ (None, 7, 7, 512) │  2,359,808 │ conv5_block3_1_r… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_bn   │ (None, 7, 7, 512) │      2,048 │ conv5_block3_2_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_2_relu │ (None, 7, 7, 512) │          0 │ conv5_block3_2_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_conv │ (None, 7, 7,      │  1,050,624 │ conv5_block3_2_r… │
# │ (Conv2D)            │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_3_bn   │ (None, 7, 7,      │      8,192 │ conv5_block3_3_c… │
# │ (BatchNormalizatio… │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_add    │ (None, 7, 7,      │          0 │ conv5_block2_out… │
# │ (Add)               │ 2048)             │            │ conv5_block3_3_b… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv5_block3_out    │ (None, 7, 7,      │          0 │ conv5_block3_add… │
# │ (Activation)        │ 2048)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ avg_pool            │ (None, 2048)      │          0 │ conv5_block3_out… │
# │ (GlobalAveragePool… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 23,587,712 (89.98 MB)
#  Trainable params: 23,534,592 (89.78 MB)
#  Non-trainable params: 53,120 (207.50 KB)

# %%
base_model.trainable = False
res50_model = Sequential()
res50_model.add(base_model)
res50_model.add(Dense(2, activation='softmax'))
res50_model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ resnet50 (Functional)           │ (None, 2048)           │    23,587,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 2)              │         4,098 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 23,591,810 (90.00 MB)
#  Trainable params: 4,098 (16.01 KB)
#  Non-trainable params: 23,587,712 (89.98 MB)

# %%
res50_model.compile(loss="categorical_crossentropy",optimizer=cus_opt,metrics=['accuracy'])
model_path = "./model/res50_model_catndog2.keras"
chechpoint = ModelCheckpoint(filepath=model_path,save_best_only=True)
early_stop = EarlyStopping(patience=100, restore_best_weights=True)
res50_model_history = res50_model.fit(train_gen, validation_data=valid_gen, epochs=1000,
                   callbacks=[chechpoint,early_stop])
plt.figure(figsize=(8,5))
plt.plot(res50_model_history.history['loss'])
plt.plot(res50_model_history.history['val_loss'])
plt.xlabel("epoches")
plt.ylabel('loss')
plt.legend(['train', 'val'])
plt.show()
# Out:
# Epoch 1/1000
# 2025-12-04 13:26:49.601310: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,64,56,56]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,64,56,56]{3,2,1,0}, f32[64,64,3,3]{3,2,1,0}, f32[64]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:26:50.581988: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:26:51.631543: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:26:52.992875: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[16,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[16,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:26:53.159477: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.14GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 16/25 ━━━━━━━━━━━━━━━━━━━━ 1s 190ms/step - accuracy: 0.6815 - loss: 0.6553
# 2025-12-04 13:26:59.898607: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:00.397914: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:00.877827: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[1,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[1,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:00.952189: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.08GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step - accuracy: 0.6871 - loss: 0.6433
# 2025-12-04 13:27:08.467813: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,128,28,28]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,128,28,28]{3,2,1,0}, f32[128,128,3,3]{3,2,1,0}, f32[128]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:09.053327: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,256,14,14]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,256,14,14]{3,2,1,0}, f32[256,256,3,3]{3,2,1,0}, f32[256]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:09.583438: I external/local_xla/xla/service/gpu/autotuning/conv_algorithm_picker.cc:546] Omitted potentially buggy algorithm eng14{k25=2} for conv (f32[2,512,7,7]{3,2,1,0}, u8[0]{0}) custom-call(f32[2,512,7,7]{3,2,1,0}, f32[512,512,3,3]{3,2,1,0}, f32[512]{0}), window={size=3x3 pad=1_1x1_1}, dim_labels=bf01_oi01->bf01, custom_call_target="__cudnn$convBiasActivationForward", backend_config={"operation_queue_id":"0","wait_on_operation_queues":[],"cudnn_conv_backend_config":{"activation_mode":"kNone","conv_result_scale":1,"side_input_scale":0,"leakyrelu_alpha":0},"force_earliest_schedule":false,"reification_cost":[]}
# 2025-12-04 13:27:09.702874: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.09GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 715ms/step - accuracy: 0.7195 - loss: 0.5933 - val_accuracy: 0.8571 - val_loss: 0.4289
# Epoch 2/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 681ms/step - accuracy: 0.7974 - loss: 0.4565 - val_accuracy: 0.8776 - val_loss: 0.3405
# Epoch 3/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 454ms/step - accuracy: 0.8416 - loss: 0.3604 - val_accuracy: 0.9184 - val_loss: 0.2768
# Epoch 4/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 416ms/step - accuracy: 0.8727 - loss: 0.3141 - val_accuracy: 0.9286 - val_loss: 0.2342
# Epoch 5/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 669ms/step - accuracy: 0.8909 - loss: 0.2786 - val_accuracy: 0.9286 - val_loss: 0.2070
# Epoch 6/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 572ms/step - accuracy: 0.9195 - loss: 0.2377 - val_accuracy: 0.9286 - val_loss: 0.1913
# Epoch 7/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 513ms/step - accuracy: 0.9299 - loss: 0.2171 - val_accuracy: 0.9388 - val_loss: 0.1712
# Epoch 8/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 798ms/step - accuracy: 0.9247 - loss: 0.2004 - val_accuracy: 0.9490 - val_loss: 0.1586
# Epoch 9/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 562ms/step - accuracy: 0.9325 - loss: 0.1827 - val_accuracy: 0.9592 - val_loss: 0.1492
# Epoch 10/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 758ms/step - accuracy: 0.9273 - loss: 0.1862 - val_accuracy: 0.9592 - val_loss: 0.1385
# Epoch 11/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 543ms/step - accuracy: 0.9481 - loss: 0.1597 - val_accuracy: 0.9592 - val_loss: 0.1300
# Epoch 12/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9506 - loss: 0.1484 - val_accuracy: 0.9592 - val_loss: 0.1237
# Epoch 13/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 731ms/step - accuracy: 0.9584 - loss: 0.1424 - val_accuracy: 0.9592 - val_loss: 0.1179
# Epoch 14/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 630ms/step - accuracy: 0.9584 - loss: 0.1294 - val_accuracy: 0.9694 - val_loss: 0.1152
# Epoch 15/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 784ms/step - accuracy: 0.9506 - loss: 0.1353 - val_accuracy: 0.9694 - val_loss: 0.1108
# Epoch 16/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 706ms/step - accuracy: 0.9558 - loss: 0.1225 - val_accuracy: 0.9694 - val_loss: 0.1077
# Epoch 17/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 785ms/step - accuracy: 0.9766 - loss: 0.1111 - val_accuracy: 0.9694 - val_loss: 0.1064
# Epoch 18/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 896ms/step - accuracy: 0.9506 - loss: 0.1192 - val_accuracy: 0.9694 - val_loss: 0.1048
# Epoch 19/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 667ms/step - accuracy: 0.9714 - loss: 0.0975 - val_accuracy: 0.9694 - val_loss: 0.1035
# Epoch 20/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9558 - loss: 0.1016 - val_accuracy: 0.9694 - val_loss: 0.1019
# Epoch 21/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 626ms/step - accuracy: 0.9662 - loss: 0.1059 - val_accuracy: 0.9694 - val_loss: 0.0994
# Epoch 22/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 953ms/step - accuracy: 0.9558 - loss: 0.1045 - val_accuracy: 0.9694 - val_loss: 0.1010
# Epoch 23/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 0.9636 - loss: 0.1006 - val_accuracy: 0.9694 - val_loss: 0.1015
# Epoch 24/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 899ms/step - accuracy: 0.9688 - loss: 0.0859 - val_accuracy: 0.9796 - val_loss: 0.1053
# Epoch 25/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.9740 - loss: 0.0836 - val_accuracy: 0.9694 - val_loss: 0.0968
# Epoch 26/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 611ms/step - accuracy: 0.9818 - loss: 0.0852 - val_accuracy: 0.9694 - val_loss: 0.0973
# Epoch 27/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 486ms/step - accuracy: 0.9766 - loss: 0.0802 - val_accuracy: 0.9694 - val_loss: 0.0973
# Epoch 28/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9714 - loss: 0.0761 - val_accuracy: 0.9796 - val_loss: 0.0959
# Epoch 29/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 698ms/step - accuracy: 0.9714 - loss: 0.0909 - val_accuracy: 0.9694 - val_loss: 0.0920
# Epoch 30/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 638ms/step - accuracy: 0.9792 - loss: 0.0735 - val_accuracy: 0.9694 - val_loss: 0.0910
# Epoch 31/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 895ms/step - accuracy: 0.9818 - loss: 0.0696 - val_accuracy: 0.9694 - val_loss: 0.0922
# Epoch 32/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 705ms/step - accuracy: 0.9870 - loss: 0.0668 - val_accuracy: 0.9796 - val_loss: 0.0938
# Epoch 33/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9766 - loss: 0.0786 - val_accuracy: 0.9796 - val_loss: 0.0940
# Epoch 34/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 750ms/step - accuracy: 0.9740 - loss: 0.0813 - val_accuracy: 0.9796 - val_loss: 0.0906
# Epoch 35/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 916ms/step - accuracy: 0.9766 - loss: 0.0661 - val_accuracy: 0.9796 - val_loss: 0.0897
# Epoch 36/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 681ms/step - accuracy: 0.9688 - loss: 0.0757 - val_accuracy: 0.9796 - val_loss: 0.0884
# Epoch 37/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 787ms/step - accuracy: 0.9792 - loss: 0.0799 - val_accuracy: 0.9694 - val_loss: 0.0849
# Epoch 38/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 659ms/step - accuracy: 0.9792 - loss: 0.0701 - val_accuracy: 0.9694 - val_loss: 0.0834
# Epoch 39/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 551ms/step - accuracy: 0.9766 - loss: 0.0697 - val_accuracy: 0.9694 - val_loss: 0.0851
# Epoch 40/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9896 - loss: 0.0505 - val_accuracy: 0.9694 - val_loss: 0.0844
# Epoch 41/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 839ms/step - accuracy: 0.9870 - loss: 0.0618 - val_accuracy: 0.9694 - val_loss: 0.0826
# Epoch 42/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 814ms/step - accuracy: 0.9974 - loss: 0.0506 - val_accuracy: 0.9796 - val_loss: 0.0888
# Epoch 43/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9870 - loss: 0.0589 - val_accuracy: 0.9796 - val_loss: 0.0839
# Epoch 44/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9792 - loss: 0.0567 - val_accuracy: 0.9694 - val_loss: 0.0814
# Epoch 45/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 533ms/step - accuracy: 0.9922 - loss: 0.0476 - val_accuracy: 0.9796 - val_loss: 0.0874
# Epoch 46/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 675ms/step - accuracy: 0.9792 - loss: 0.0618 - val_accuracy: 0.9694 - val_loss: 0.0825
# Epoch 47/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 644ms/step - accuracy: 0.9792 - loss: 0.0588 - val_accuracy: 0.9796 - val_loss: 0.0831
# Epoch 48/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 930ms/step - accuracy: 0.9896 - loss: 0.0504 - val_accuracy: 0.9796 - val_loss: 0.0868
# Epoch 49/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 817ms/step - accuracy: 0.9818 - loss: 0.0555 - val_accuracy: 0.9796 - val_loss: 0.0832
# Epoch 50/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9844 - loss: 0.0420 - val_accuracy: 0.9694 - val_loss: 0.0796
# Epoch 51/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 0.9818 - loss: 0.0607 - val_accuracy: 0.9796 - val_loss: 0.0826
# Epoch 52/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 626ms/step - accuracy: 0.9870 - loss: 0.0585 - val_accuracy: 0.9796 - val_loss: 0.0861
# Epoch 53/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9792 - loss: 0.0554 - val_accuracy: 0.9694 - val_loss: 0.0782
# Epoch 54/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 544ms/step - accuracy: 0.9740 - loss: 0.0622 - val_accuracy: 0.9796 - val_loss: 0.0879
# Epoch 55/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 752ms/step - accuracy: 0.9844 - loss: 0.0472 - val_accuracy: 0.9796 - val_loss: 0.0829
# Epoch 56/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 819ms/step - accuracy: 0.9896 - loss: 0.0372 - val_accuracy: 0.9796 - val_loss: 0.0845
# Epoch 57/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 757ms/step - accuracy: 0.9870 - loss: 0.0374 - val_accuracy: 0.9796 - val_loss: 0.0806
# Epoch 58/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 876ms/step - accuracy: 0.9896 - loss: 0.0452 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 59/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 827ms/step - accuracy: 0.9818 - loss: 0.0534 - val_accuracy: 0.9796 - val_loss: 0.0801
# Epoch 60/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 855ms/step - accuracy: 0.9922 - loss: 0.0477 - val_accuracy: 0.9796 - val_loss: 0.0796
# Epoch 61/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 946ms/step - accuracy: 0.9948 - loss: 0.0301 - val_accuracy: 0.9796 - val_loss: 0.0821
# Epoch 62/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 732ms/step - accuracy: 0.9792 - loss: 0.0550 - val_accuracy: 0.9796 - val_loss: 0.0801
# Epoch 63/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 798ms/step - accuracy: 0.9922 - loss: 0.0483 - val_accuracy: 0.9796 - val_loss: 0.0791
# Epoch 64/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 711ms/step - accuracy: 0.9922 - loss: 0.0445 - val_accuracy: 0.9796 - val_loss: 0.0802
# Epoch 65/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 837ms/step - accuracy: 0.9948 - loss: 0.0362 - val_accuracy: 0.9796 - val_loss: 0.0885
# Epoch 66/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9896 - loss: 0.0450 - val_accuracy: 0.9796 - val_loss: 0.0764
# Epoch 67/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 465ms/step - accuracy: 0.9818 - loss: 0.0516 - val_accuracy: 0.9796 - val_loss: 0.0784
# Epoch 68/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 765ms/step - accuracy: 0.9818 - loss: 0.0417 - val_accuracy: 0.9796 - val_loss: 0.0786
# Epoch 69/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 787ms/step - accuracy: 0.9896 - loss: 0.0385 - val_accuracy: 0.9796 - val_loss: 0.0781
# Epoch 70/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 904ms/step - accuracy: 0.9922 - loss: 0.0304 - val_accuracy: 0.9796 - val_loss: 0.0767
# Epoch 71/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 689ms/step - accuracy: 0.9844 - loss: 0.0447 - val_accuracy: 0.9796 - val_loss: 0.0822
# Epoch 72/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 747ms/step - accuracy: 0.9870 - loss: 0.0462 - val_accuracy: 0.9796 - val_loss: 0.0786
# Epoch 73/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 872ms/step - accuracy: 0.9896 - loss: 0.0398 - val_accuracy: 0.9796 - val_loss: 0.0787
# Epoch 74/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 750ms/step - accuracy: 0.9896 - loss: 0.0409 - val_accuracy: 0.9796 - val_loss: 0.0812
# Epoch 75/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 762ms/step - accuracy: 0.9948 - loss: 0.0314 - val_accuracy: 0.9796 - val_loss: 0.0787
# Epoch 76/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 802ms/step - accuracy: 0.9896 - loss: 0.0343 - val_accuracy: 0.9796 - val_loss: 0.0791
# Epoch 77/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9948 - loss: 0.0375 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 78/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 564ms/step - accuracy: 0.9948 - loss: 0.0269 - val_accuracy: 0.9796 - val_loss: 0.0781
# Epoch 79/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 923ms/step - accuracy: 0.9870 - loss: 0.0404 - val_accuracy: 0.9796 - val_loss: 0.0789
# Epoch 80/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 821ms/step - accuracy: 0.9896 - loss: 0.0333 - val_accuracy: 0.9796 - val_loss: 0.0856
# Epoch 81/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 836ms/step - accuracy: 0.9922 - loss: 0.0337 - val_accuracy: 0.9796 - val_loss: 0.0816
# Epoch 82/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 892ms/step - accuracy: 0.9896 - loss: 0.0332 - val_accuracy: 0.9796 - val_loss: 0.0808
# Epoch 83/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 705ms/step - accuracy: 0.9948 - loss: 0.0397 - val_accuracy: 0.9796 - val_loss: 0.0794
# Epoch 84/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9896 - loss: 0.0311 - val_accuracy: 0.9796 - val_loss: 0.0782
# Epoch 85/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 978ms/step - accuracy: 0.9870 - loss: 0.0318 - val_accuracy: 0.9796 - val_loss: 0.0824
# Epoch 86/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 944ms/step - accuracy: 0.9870 - loss: 0.0327 - val_accuracy: 0.9796 - val_loss: 0.0792
# Epoch 87/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9922 - loss: 0.0407 - val_accuracy: 0.9796 - val_loss: 0.0802
# Epoch 88/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9896 - loss: 0.0306 - val_accuracy: 0.9796 - val_loss: 0.0793
# Epoch 89/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 767ms/step - accuracy: 0.9922 - loss: 0.0261 - val_accuracy: 0.9796 - val_loss: 0.0860
# Epoch 90/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 874ms/step - accuracy: 0.9896 - loss: 0.0323 - val_accuracy: 0.9796 - val_loss: 0.0790
# Epoch 91/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 616ms/step - accuracy: 0.9922 - loss: 0.0296 - val_accuracy: 0.9796 - val_loss: 0.0769
# Epoch 92/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 869ms/step - accuracy: 0.9922 - loss: 0.0304 - val_accuracy: 0.9796 - val_loss: 0.0902
# Epoch 93/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 864ms/step - accuracy: 0.9948 - loss: 0.0314 - val_accuracy: 0.9796 - val_loss: 0.0798
# Epoch 94/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 825ms/step - accuracy: 0.9922 - loss: 0.0333 - val_accuracy: 0.9796 - val_loss: 0.0840
# Epoch 95/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 775ms/step - accuracy: 0.9948 - loss: 0.0223 - val_accuracy: 0.9796 - val_loss: 0.0798
# Epoch 96/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 908ms/step - accuracy: 0.9948 - loss: 0.0214 - val_accuracy: 0.9796 - val_loss: 0.0783
# Epoch 97/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 919ms/step - accuracy: 0.9870 - loss: 0.0408 - val_accuracy: 0.9796 - val_loss: 0.0778
# Epoch 98/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 691ms/step - accuracy: 0.9922 - loss: 0.0277 - val_accuracy: 0.9796 - val_loss: 0.0850
# Epoch 99/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 23s 949ms/step - accuracy: 0.9792 - loss: 0.0465 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 100/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 872ms/step - accuracy: 0.9896 - loss: 0.0327 - val_accuracy: 0.9796 - val_loss: 0.0808
# Epoch 101/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 33s 1s/step - accuracy: 0.9974 - loss: 0.0252 - val_accuracy: 0.9796 - val_loss: 0.0757
# Epoch 102/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9922 - loss: 0.0289 - val_accuracy: 0.9796 - val_loss: 0.0771
# Epoch 103/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 35s 1s/step - accuracy: 0.9922 - loss: 0.0306 - val_accuracy: 0.9796 - val_loss: 0.0755
# Epoch 104/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 560ms/step - accuracy: 1.0000 - loss: 0.0191 - val_accuracy: 0.9796 - val_loss: 0.0806
# Epoch 105/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 22s 894ms/step - accuracy: 1.0000 - loss: 0.0216 - val_accuracy: 0.9796 - val_loss: 0.0767
# Epoch 106/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 862ms/step - accuracy: 0.9974 - loss: 0.0224 - val_accuracy: 0.9796 - val_loss: 0.0799
# Epoch 107/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9870 - loss: 0.0383 - val_accuracy: 0.9796 - val_loss: 0.0813
# Epoch 108/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9922 - loss: 0.0271 - val_accuracy: 0.9796 - val_loss: 0.0832
# Epoch 109/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 811ms/step - accuracy: 0.9922 - loss: 0.0270 - val_accuracy: 0.9796 - val_loss: 0.0787
# Epoch 110/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 24s 905ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9796 - val_loss: 0.0798
# Epoch 111/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9974 - loss: 0.0218 - val_accuracy: 0.9796 - val_loss: 0.0826
# Epoch 112/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.9974 - loss: 0.0181 - val_accuracy: 0.9796 - val_loss: 0.0880
# Epoch 113/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 34s 1s/step - accuracy: 0.9870 - loss: 0.0350 - val_accuracy: 0.9796 - val_loss: 0.0804
# Epoch 114/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 19s 721ms/step - accuracy: 0.9922 - loss: 0.0311 - val_accuracy: 0.9796 - val_loss: 0.0823
# Epoch 115/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.9844 - loss: 0.0370 - val_accuracy: 0.9796 - val_loss: 0.0787
# Epoch 116/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 28s 1s/step - accuracy: 0.9896 - loss: 0.0291 - val_accuracy: 0.9796 - val_loss: 0.0824
# Epoch 117/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 1.0000 - loss: 0.0207 - val_accuracy: 0.9796 - val_loss: 0.0859
# Epoch 118/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.9896 - loss: 0.0293 - val_accuracy: 0.9796 - val_loss: 0.0763
# Epoch 119/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 27s 1s/step - accuracy: 0.9948 - loss: 0.0315 - val_accuracy: 0.9796 - val_loss: 0.0769
# Epoch 120/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.9974 - loss: 0.0174 - val_accuracy: 0.9796 - val_loss: 0.0879
# Epoch 121/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 16s 632ms/step - accuracy: 0.9922 - loss: 0.0280 - val_accuracy: 0.9796 - val_loss: 0.0806
# Epoch 122/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 515ms/step - accuracy: 0.9896 - loss: 0.0309 - val_accuracy: 0.9796 - val_loss: 0.0815
# Epoch 123/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 593ms/step - accuracy: 1.0000 - loss: 0.0184 - val_accuracy: 0.9694 - val_loss: 0.0776
# Epoch 124/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 543ms/step - accuracy: 0.9896 - loss: 0.0365 - val_accuracy: 0.9796 - val_loss: 0.0835
# Epoch 125/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 601ms/step - accuracy: 0.9922 - loss: 0.0261 - val_accuracy: 0.9796 - val_loss: 0.0811
# Epoch 126/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 485ms/step - accuracy: 1.0000 - loss: 0.0136 - val_accuracy: 0.9796 - val_loss: 0.0834
# Epoch 127/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 15s 590ms/step - accuracy: 0.9922 - loss: 0.0219 - val_accuracy: 0.9796 - val_loss: 0.0830
# Epoch 128/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 561ms/step - accuracy: 0.9896 - loss: 0.0319 - val_accuracy: 0.9796 - val_loss: 0.0826
# Epoch 129/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 14s 540ms/step - accuracy: 1.0000 - loss: 0.0199 - val_accuracy: 0.9796 - val_loss: 0.0816
# Epoch 130/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 820ms/step - accuracy: 0.9974 - loss: 0.0196 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 131/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 72182s 3008s/step - accuracy: 0.9948 - loss: 0.0206 - val_accuracy: 0.9796 - val_loss: 0.0794
# Epoch 132/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 232ms/step - accuracy: 0.9974 - loss: 0.0184 - val_accuracy: 0.9796 - val_loss: 0.0775
# Epoch 133/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 202ms/step - accuracy: 0.9948 - loss: 0.0241 - val_accuracy: 0.9796 - val_loss: 0.0796
# Epoch 134/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 1.0000 - loss: 0.0124 - val_accuracy: 0.9796 - val_loss: 0.0815
# Epoch 135/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 174ms/step - accuracy: 1.0000 - loss: 0.0143 - val_accuracy: 0.9796 - val_loss: 0.0799
# Epoch 136/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 4s 163ms/step - accuracy: 0.9974 - loss: 0.0219 - val_accuracy: 0.9796 - val_loss: 0.0879
# Epoch 137/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.9818 - loss: 0.0379 - val_accuracy: 0.9796 - val_loss: 0.0834
# Epoch 138/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9948 - loss: 0.0259 - val_accuracy: 0.9796 - val_loss: 0.0797
# Epoch 139/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 0.9948 - loss: 0.0138 - val_accuracy: 0.9796 - val_loss: 0.0798
# Epoch 140/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9948 - loss: 0.0231 - val_accuracy: 0.9796 - val_loss: 0.0745
# Epoch 141/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7916s 330s/step - accuracy: 0.9948 - loss: 0.0234 - val_accuracy: 0.9796 - val_loss: 0.0762
# Epoch 142/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.9974 - loss: 0.0161 - val_accuracy: 0.9796 - val_loss: 0.0817
# Epoch 143/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9922 - loss: 0.0338 - val_accuracy: 0.9796 - val_loss: 0.0904
# Epoch 144/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 0.9844 - loss: 0.0310 - val_accuracy: 0.9796 - val_loss: 0.0859
# Epoch 145/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 189ms/step - accuracy: 0.9922 - loss: 0.0234 - val_accuracy: 0.9796 - val_loss: 0.0856
# Epoch 146/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9974 - loss: 0.0155 - val_accuracy: 0.9796 - val_loss: 0.0787
# Epoch 147/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 200ms/step - accuracy: 0.9896 - loss: 0.0309 - val_accuracy: 0.9796 - val_loss: 0.0781
# Epoch 148/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 303ms/step - accuracy: 0.9974 - loss: 0.0178 - val_accuracy: 0.9796 - val_loss: 0.0784
# Epoch 149/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9796 - val_loss: 0.0782
# Epoch 150/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 256ms/step - accuracy: 0.9922 - loss: 0.0302 - val_accuracy: 0.9796 - val_loss: 0.0906
# Epoch 151/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 257ms/step - accuracy: 0.9922 - loss: 0.0207 - val_accuracy: 0.9796 - val_loss: 0.0801
# Epoch 152/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 254ms/step - accuracy: 0.9974 - loss: 0.0165 - val_accuracy: 0.9796 - val_loss: 0.0767
# Epoch 153/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 306ms/step - accuracy: 1.0000 - loss: 0.0117 - val_accuracy: 0.9796 - val_loss: 0.0767
# Epoch 154/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 250ms/step - accuracy: 0.9844 - loss: 0.0251 - val_accuracy: 0.9796 - val_loss: 0.0792
# Epoch 155/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 222ms/step - accuracy: 0.9974 - loss: 0.0172 - val_accuracy: 0.9796 - val_loss: 0.0830
# Epoch 156/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9948 - loss: 0.0166 - val_accuracy: 0.9796 - val_loss: 0.0860
# Epoch 157/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 274ms/step - accuracy: 0.9896 - loss: 0.0257 - val_accuracy: 0.9796 - val_loss: 0.0903
# Epoch 158/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 344ms/step - accuracy: 1.0000 - loss: 0.0146 - val_accuracy: 0.9796 - val_loss: 0.0904
# Epoch 159/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 259ms/step - accuracy: 0.9974 - loss: 0.0165 - val_accuracy: 0.9796 - val_loss: 0.0848
# Epoch 160/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 248ms/step - accuracy: 0.9948 - loss: 0.0140 - val_accuracy: 0.9796 - val_loss: 0.0927
# Epoch 161/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 242ms/step - accuracy: 0.9896 - loss: 0.0184 - val_accuracy: 0.9796 - val_loss: 0.0838
# Epoch 162/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 264ms/step - accuracy: 1.0000 - loss: 0.0098 - val_accuracy: 0.9796 - val_loss: 0.0873
# Epoch 163/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 8s 305ms/step - accuracy: 0.9896 - loss: 0.0279 - val_accuracy: 0.9796 - val_loss: 0.0790
# Epoch 164/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 272ms/step - accuracy: 1.0000 - loss: 0.0111 - val_accuracy: 0.9796 - val_loss: 0.0807
# Epoch 165/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 78349s 3265s/step - accuracy: 0.9948 - loss: 0.0202 - val_accuracy: 0.9796 - val_loss: 0.0866
# Epoch 166/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 11s 448ms/step - accuracy: 0.9948 - loss: 0.0162 - val_accuracy: 0.9796 - val_loss: 0.0795
# Epoch 167/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9948 - loss: 0.0185 - val_accuracy: 0.9796 - val_loss: 0.0860
# Epoch 168/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9922 - loss: 0.0207 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 169/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 235ms/step - accuracy: 0.9948 - loss: 0.0201 - val_accuracy: 0.9796 - val_loss: 0.0831
# Epoch 170/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 240ms/step - accuracy: 0.9922 - loss: 0.0224 - val_accuracy: 0.9796 - val_loss: 0.0756
# Epoch 171/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 0.9948 - loss: 0.0177 - val_accuracy: 0.9796 - val_loss: 0.0831
# Epoch 172/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9974 - loss: 0.0124 - val_accuracy: 0.9796 - val_loss: 0.0775
# Epoch 173/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9974 - loss: 0.0148 - val_accuracy: 0.9796 - val_loss: 0.0918
# Epoch 174/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7655s 319s/step - accuracy: 0.9948 - loss: 0.0146 - val_accuracy: 0.9796 - val_loss: 0.0818
# Epoch 175/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9974 - loss: 0.0134 - val_accuracy: 0.9796 - val_loss: 0.0823
# Epoch 176/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 188ms/step - accuracy: 0.9974 - loss: 0.0153 - val_accuracy: 0.9796 - val_loss: 0.0830
# Epoch 177/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 183ms/step - accuracy: 0.9948 - loss: 0.0116 - val_accuracy: 0.9796 - val_loss: 0.0892
# Epoch 178/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 177ms/step - accuracy: 0.9948 - loss: 0.0202 - val_accuracy: 0.9796 - val_loss: 0.0857
# Epoch 179/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9974 - loss: 0.0158 - val_accuracy: 0.9796 - val_loss: 0.0828
# Epoch 180/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 287ms/step - accuracy: 0.9948 - loss: 0.0222 - val_accuracy: 0.9796 - val_loss: 0.0950
# Epoch 181/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 1.0000 - loss: 0.0131 - val_accuracy: 0.9796 - val_loss: 0.0980
# Epoch 182/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 225ms/step - accuracy: 0.9948 - loss: 0.0149 - val_accuracy: 0.9796 - val_loss: 0.0798
# Epoch 183/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9948 - loss: 0.0177 - val_accuracy: 0.9796 - val_loss: 0.0826
# Epoch 184/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 221ms/step - accuracy: 0.9974 - loss: 0.0123 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 185/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 218ms/step - accuracy: 0.9974 - loss: 0.0160 - val_accuracy: 0.9796 - val_loss: 0.0863
# Epoch 186/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9922 - loss: 0.0152 - val_accuracy: 0.9796 - val_loss: 0.0785
# Epoch 187/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 223ms/step - accuracy: 0.9896 - loss: 0.0209 - val_accuracy: 0.9796 - val_loss: 0.0869
# Epoch 188/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9948 - loss: 0.0159 - val_accuracy: 0.9796 - val_loss: 0.0811
# Epoch 189/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 1.0000 - loss: 0.0110 - val_accuracy: 0.9796 - val_loss: 0.0829
# Epoch 190/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9974 - loss: 0.0102 - val_accuracy: 0.9796 - val_loss: 0.0841
# Epoch 191/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9974 - loss: 0.0142 - val_accuracy: 0.9796 - val_loss: 0.0797
# Epoch 192/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 283ms/step - accuracy: 1.0000 - loss: 0.0125 - val_accuracy: 0.9796 - val_loss: 0.0784
# Epoch 193/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 0.9948 - loss: 0.0140 - val_accuracy: 0.9796 - val_loss: 0.0854
# Epoch 194/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9974 - loss: 0.0132 - val_accuracy: 0.9796 - val_loss: 0.0788
# Epoch 195/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 209ms/step - accuracy: 1.0000 - loss: 0.0137 - val_accuracy: 0.9796 - val_loss: 0.0821
# Epoch 196/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 224ms/step - accuracy: 0.9974 - loss: 0.0159 - val_accuracy: 0.9796 - val_loss: 0.0887
# Epoch 197/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 205ms/step - accuracy: 0.9974 - loss: 0.0114 - val_accuracy: 0.9796 - val_loss: 0.0775
# Epoch 198/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 1.0000 - loss: 0.0089 - val_accuracy: 0.9796 - val_loss: 0.0778
# Epoch 199/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.9796 - val_loss: 0.0805
# Epoch 200/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 215ms/step - accuracy: 0.9870 - loss: 0.0231 - val_accuracy: 0.9796 - val_loss: 0.0809
# Epoch 201/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 211ms/step - accuracy: 0.9974 - loss: 0.0111 - val_accuracy: 0.9796 - val_loss: 0.0814
# Epoch 202/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 81357s 3390s/step - accuracy: 0.9974 - loss: 0.0134 - val_accuracy: 0.9796 - val_loss: 0.0791
# Epoch 203/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12s 461ms/step - accuracy: 0.9922 - loss: 0.0193 - val_accuracy: 0.9796 - val_loss: 0.0895
# Epoch 204/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 244ms/step - accuracy: 0.9974 - loss: 0.0120 - val_accuracy: 0.9796 - val_loss: 0.0874
# Epoch 205/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 207ms/step - accuracy: 0.9948 - loss: 0.0144 - val_accuracy: 0.9796 - val_loss: 0.0824
# Epoch 206/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 0.9974 - loss: 0.0141 - val_accuracy: 0.9796 - val_loss: 0.0851
# Epoch 207/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 190ms/step - accuracy: 0.9974 - loss: 0.0116 - val_accuracy: 0.9796 - val_loss: 0.0830
# Epoch 208/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 237ms/step - accuracy: 1.0000 - loss: 0.0100 - val_accuracy: 0.9796 - val_loss: 0.0838
# Epoch 209/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 231ms/step - accuracy: 0.9948 - loss: 0.0150 - val_accuracy: 0.9796 - val_loss: 0.0939
# Epoch 210/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 192ms/step - accuracy: 0.9948 - loss: 0.0170 - val_accuracy: 0.9796 - val_loss: 0.0927
# Epoch 211/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 193ms/step - accuracy: 1.0000 - loss: 0.0129 - val_accuracy: 0.9796 - val_loss: 0.0897
# Epoch 212/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 12023s 501s/step - accuracy: 0.9948 - loss: 0.0141 - val_accuracy: 0.9796 - val_loss: 0.0881
# Epoch 213/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 203ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9796 - val_loss: 0.0811
# Epoch 214/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 180ms/step - accuracy: 1.0000 - loss: 0.0105 - val_accuracy: 0.9796 - val_loss: 0.0770
# Epoch 215/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 176ms/step - accuracy: 0.9974 - loss: 0.0113 - val_accuracy: 0.9796 - val_loss: 0.0889
# Epoch 216/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 1.0000 - loss: 0.0074 - val_accuracy: 0.9796 - val_loss: 0.0865
# Epoch 217/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 179ms/step - accuracy: 0.9974 - loss: 0.0102 - val_accuracy: 0.9796 - val_loss: 0.0932
# Epoch 218/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 182ms/step - accuracy: 1.0000 - loss: 0.0115 - val_accuracy: 0.9796 - val_loss: 0.0888
# Epoch 219/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 181ms/step - accuracy: 0.9896 - loss: 0.0186 - val_accuracy: 0.9796 - val_loss: 0.0801
# Epoch 220/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 204ms/step - accuracy: 0.9948 - loss: 0.0131 - val_accuracy: 0.9796 - val_loss: 0.0794
# Epoch 221/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 208ms/step - accuracy: 0.9974 - loss: 0.0107 - val_accuracy: 0.9796 - val_loss: 0.0844
# Epoch 222/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 1.0000 - loss: 0.0061 - val_accuracy: 0.9694 - val_loss: 0.0993
# Epoch 223/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 212ms/step - accuracy: 0.9974 - loss: 0.0116 - val_accuracy: 0.9796 - val_loss: 0.0885
# Epoch 224/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9948 - loss: 0.0106 - val_accuracy: 0.9796 - val_loss: 0.0811
# Epoch 225/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 238ms/step - accuracy: 1.0000 - loss: 0.0080 - val_accuracy: 0.9796 - val_loss: 0.0829
# Epoch 226/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 206ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9796 - val_loss: 0.0937
# Epoch 227/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9796 - val_loss: 0.0853
# Epoch 228/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 230ms/step - accuracy: 0.9974 - loss: 0.0119 - val_accuracy: 0.9796 - val_loss: 0.0829
# Epoch 229/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 194ms/step - accuracy: 0.9974 - loss: 0.0127 - val_accuracy: 0.9796 - val_loss: 0.0781
# Epoch 230/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 7s 284ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9796 - val_loss: 0.0848
# Epoch 231/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 216ms/step - accuracy: 0.9948 - loss: 0.0158 - val_accuracy: 0.9796 - val_loss: 0.0839
# Epoch 232/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 1.0000 - loss: 0.0088 - val_accuracy: 0.9796 - val_loss: 0.0902
# Epoch 233/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 220ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9796 - val_loss: 0.0814
# Epoch 234/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 226ms/step - accuracy: 1.0000 - loss: 0.0097 - val_accuracy: 0.9694 - val_loss: 0.0981
# Epoch 235/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 216ms/step - accuracy: 0.9948 - loss: 0.0157 - val_accuracy: 0.9796 - val_loss: 0.0907
# Epoch 236/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 236ms/step - accuracy: 0.9974 - loss: 0.0097 - val_accuracy: 0.9796 - val_loss: 0.0845
# Epoch 237/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 217ms/step - accuracy: 0.9922 - loss: 0.0182 - val_accuracy: 0.9796 - val_loss: 0.0977
# Epoch 238/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 5s 213ms/step - accuracy: 0.9974 - loss: 0.0119 - val_accuracy: 0.9796 - val_loss: 0.0886
# Epoch 239/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 6s 215ms/step - accuracy: 1.0000 - loss: 0.0084 - val_accuracy: 0.9796 - val_loss: 0.0804
# Epoch 240/1000
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 67168s 2799s/step - accuracy: 0.9948 - loss: 0.0134 - val_accuracy: 0.9796 - val_loss: 0.0919

# %%
# ✅ 모델 로드
res50_best_model = load_model("./model/res50_catndog.keras")

# ✅ 클래스 이름 추출
class_indices = valid_gen.class_indices
class_names = [k for k, v in sorted(class_indices.items(), key=lambda x: x[1])]

# ✅ 전체 validation 데이터로 예측
cnn_pred = res50_best_model.predict(valid_gen, verbose=1)
pred_values = np.argmax(cnn_pred, axis=1)
true_values = valid_gen.classes  # 전체 정답

# ✅정확도 출력
acc = accuracy_score(true_values, pred_values)
print(f"\n[전체 Validation Accuracy] {acc:.4f}")

# ✅ 시각화용: 소량 배치만 가져오기
sample_batch, label_batch = next(valid_gen)
sample_pred = res50_best_model.predict(sample_batch)
sample_pred_values = np.argmax(sample_pred, axis=1)
sample_true_values = np.argmax(label_batch, axis=1)

# ✅ 시각화: 이미지 복구 후 출력
def deprocess_input(x):
    """ResNet의 preprocess_input을 반대로 적용 (BGR→RGB + 평균값 복원)"""
    x = x.copy()
    # ImageNet 평균값 (BGR 순)
    mean = [103.939, 116.779, 123.68]
    x[..., 0] += mean[0]  # B
    x[..., 1] += mean[1]  # G
    x[..., 2] += mean[2]  # R
    x = x[..., ::-1]  # BGR → RGB
    return np.clip(x / 255.0, 0, 1)  # matplotlib은 0~1 사이값을 기대함

# ✅ 이미지 시각화
fig = plt.figure(figsize=(12, 12))
fig.subplots_adjust(hspace=0.3)
num_images = min(16, sample_batch.shape[0])

for i in range(num_images):
    ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
    img = deprocess_input(sample_batch[i])
    ax.imshow(img)
    pred_label = class_names[sample_pred_values[i]]
    true_label = class_names[sample_true_values[i]]
    color = 'green' if pred_label == true_label else 'red'
    ax.set_title(f"Pred: {pred_label}", color=color, fontsize=12)
plt.show()

# ✅ 전체 평가
loss, acc = res50_best_model.evaluate(valid_gen, verbose=1)
print(f"\n[모델 평가 결과] Loss: {loss:.4f}, Accuracy: {acc:.4f}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 # ✅ 모델 로드
# ----> 2 res50_best_model = load_model("./model/res50_catndog.keras")
#       4 # ✅ 클래스 이름 추출
#       5 class_indices = valid_gen.class_indices
#
# File ~/miniforge3/envs/tf/lib/python3.10/site-packages/keras/src/saving/saving_api.py:203, in load_model(filepath, custom_objects, compile, safe_mode)
#     196     return legacy_h5_format.load_model_from_hdf5(
#     197         filepath,
#     198         custom_objects=custom_objects,
#     199         compile=compile,
#     200         safe_mode=safe_mode,
#     201     )
#     202 elif str(filepath).endswith(".keras"):
# --> 203     raise ValueError(
#     204         f"File not found: filepath={filepath}. "
#     205         "Please ensure the file is an accessible `.keras` "
#     206         "zip file."
#     207     )
#     208 else:
#     209     raise ValueError(
#     210         f"File format not supported: filepath={filepath}. "
#     211         "Keras 3 only supports V3 `.keras` files and "
#    (...)
#     220         "might have a different name)."
#     221     )
#
# ValueError: File not found: filepath=./model/res50_catndog.keras. Please ensure the file is an accessible `.keras` zip file.
