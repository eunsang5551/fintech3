# %%
import requests
import pandas as pd
import re
from dotenv import load_dotenv
import os
load_dotenv("./data/.env_naver")
# Out:
# False

# %%
page_num = 1
total_pages = 1

all_data = []
while page_num <= total_pages:
    url = "https://openapi.gg.go.kr/TBGGDLNGPRCAPTTRDSRCM"
    payload = dict(key=os.getenv("gg_data"), type="json", pIndex=page_num, pSize=1000)
    r = requests.get(url, params=payload)
    print(r.url)
#     print(r.status_code)
    if page_num == 1:
        total_pages = data['TBGGDLNGPRCAPTTRDSRCM'][0]['head'][0]['list_total_count'] // 1000 + 1  
    else:
        pass
     
    response = r.json()
    all_data.append(pd.DataFrame(response['TBGGDLNGPRCAPTTRDSRCM'][1]['row']))
    page_num += 1

df = pd.concat(all_data)
df = df.reset_index(drop=True)
df
# Out:
# https://openapi.gg.go.kr/TBGGDLNGPRCAPTTRDSRCM?type=json&pIndex=1&pSize=1000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 12
#      10 #     print(r.status_code)
#      11     if page_num == 1:
# ---> 12         total_pages = data['TBGGDLNGPRCAPTTRDSRCM'][0]['head'][0]['list_total_count'] // 1000 + 1
#      13     else:
#      14         pass
#
# NameError: name 'data' is not defined

# %%
new_cols = ["번호",
"주소",
"지번주소",
"지번본번",
"지번부번",
"단지명",
"전용면적",
"계약연월",
"계약일",
"거래금액",
"층명",
"건축년도",
"도로명",
"정제완료여부",
"생성일자",
"정제지번주소",
"정제도로명주소",
"정제우편번호",
"정제WGS84경도",
"정제WGS84위도",
"정제관리번호",
"정제결과코드",
"정제주소구분코드",
"정제시스템구분코드",
"정제일시",
"정제불가여부",
"정제상태코드"]

# %%
df.columns = new_cols
df

# %%
df.info()

# %%
df['도로명']

# %%
df.columns

# %%
result_df = df[['번호', '단지명', '전용면적', '계약연월', '계약일', '거래금액', '정제상태코드']]
result_df
